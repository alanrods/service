# %% [markdown]
# # LSTM Corpus Creation

# %%
import io
import numpy as np
import pandas as pd

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %%
import pickle

# %%
tokenizer = Tokenizer(num_words=20000,lower=False)

# %%
def read_ds(ds_list):
    supreme = []
    for tweet in ds_list:
        supreme.append(tweet.split('|',2)[-2:])
    return supreme

def  change_value(strings):
    if strings == 'ironic':
        return 1
    else:
        return 0

# %%
def saveDict(path, sequence_dict):
    return np.save(path, sequence_dict)
    

def getSequence(tweets_text):
    tokenizer.fit_on_texts(tweets_text)
    seq_dict = tokenizer.word_index
    return tokenizer.texts_to_sequences(tweets_text), seq_dict


def list2vec(corpus_list):
    arr = np.array(read_ds(corpus_list))
    df = pd.DataFrame(data=arr,columns=['cat','tweet'])
    alter = df['cat'].apply(change_value)
    df.insert(loc=2,column='category',value=alter)
    tweets = df['tweet'].iloc[:]
    tweet_sec, s_dict = getSequence(tweets)
    df.insert(loc=3,column='tweet_sec', value=tweet_sec)
    return df[['category','tweet_sec']], s_dict

# %% [markdown]
# # IMPORTANT CLARIFICATION!!!
# In order to build a data set from easy way, for saving and reading, we used the *Pickle Library*, in this particular case we save and read a **Pandas DataFrame**. Because, we consider this is the best way for setting up a data set for future use in any kind of ANN Model, but we have to say, this is not for human purposes, because the nature of *Pickle Library*, try to read the *txt file* can result impossible.
#
# For this situation, we also save a data set copy by using a **Pandas Method** which is called **to_csv()**, thus we have a readable data set. We do not consider this path for saving and reading the data sets, because we found a **big trouble** when we try to save the *data frame*, **Pandas** saves a string instead of vector (**tweet_sec**), and we prefer to avoid this trouble in order to not increase the complexy of the project.

# %%
df = pd.read_csv('./data/ann/vectors_10_90_readable.txt',sep='|')

# %%
thing = df.tweet_sec.iloc[::][0] 
print thing
print type(thing)
# Out:
# [1750, 1550, 2072, 1, 46, 792, 588, 1750, 1550, 3982, 10, 46, 5925, 2, 32, 5505, 1, 205, 4, 3]
# <type 'str'>

# %% [markdown]
# ### Corpus with 10-90 distribution

# %%
with io.open('data/corpus_10_90.txt','r',encoding='utf8') as f:
    corpus_10_90 = f.readlines()

# %%
vecorp_10_90 = list2vec(corpus_10_90) 
vecorp_10_90.count()
# Out:
# category     76530
# tweet_sec    76530
# dtype: int64

# %%
vecorp_10_90.head()
# Out:
#    category                                          tweet_sec
# 0         0  [1750, 1550, 2072, 1, 46, 792, 588, 1750, 1550...
# 1         0                    [43, 1562, 15, 13, 438, 9, 130]
# 2         1  [309, 25, 296, 31, 310, 91, 25, 145, 294, 21, ...
# 3         0  [24, 4522, 1385, 4415, 23, 21, 25, 2850, 6146,...
# 4         0  [762, 24, 17280, 2, 645, 7, 21, 511, 40, 15364...

# %%
vecfile = open("./data/ann/vectors_10_90.txt","w")
pickle.dump(vecorp_10_90, vecfile)

# %%
vecorp_10_90.to_csv('./data/ann/vectors_10_90_readable.txt',sep='|',index=False)

# %% [markdown]
# ### Corpus with 30-70 distribution

# %%
with io.open('data/corpus_30_70.txt','r',encoding='utf8') as f:
    corpus_30_70 = f.readlines()

# %%
vecorp_30_70 = list2vec(corpus_30_70)
vecorp_30_70.count()
# Out:
# category     25510
# tweet_sec    25510
# dtype: int64

# %%
vecorp_30_70.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5302111217d0> in <module>()
# ----> 1 vecorp_30_70.head()
#
# NameError: name 'vecorp_30_70' is not defined

# %%
vecfile = open("./data/ann/vectors_30_70.txt","w")
pickle.dump(vecorp_30_70, vecfile)

# %%
vecorp_30_70.to_csv('./data/ann/vectors_30_70_readable.txt',sep='|',index=False)

# %% [markdown]
# ### Corpus with 50-50 distribution

# %%
with io.open('data/corpus_50_50.txt','r',encoding='utf8') as f:
    corpus_50_50 = f.readlines()

# %%
vecorp_50_50, dict_50_50 = list2vec(corpus_50_50)
vecorp_50_50.count()
# Out:
# category     15306
# tweet_sec    15306
# dtype: int64

# %%
vecorp_50_50.head()
# Out:
#    category                                          tweet_sec
# 0         1                      [268, 459, 146, 2, 470, 4493]
# 1         1                              [2264, 7, 9784, 3050]
# 2         0  [80, 172, 35, 1, 14, 39, 2265, 7, 9785, 2266, ...
# 3         1  [107, 41, 21, 471, 9, 659, 5, 216, 300, 5, 7, ...
# 4         1                       [562, 106, 29, 563, 29, 422]

# %%
dict_50_50
# Out:
# {u'\U0001f49d\U0001f49d\U0001f49d': 22167,
#  u'Acostumbres': 21420,
#  u'MILLONARIOOOOS': 11703,
#  u'luanco': 19455,
#  u'bloqueos': 4314,
#  u'Dago': 16574,
#  u'\xa1Por': 18271,
#  u'1a\xf1o': 26602,
#  u'destino2016': 7422,
#  u'Caer': 25478,
#  u'trotar': 27787,
#  u'Moreira': 18140,
#  u'igual': 228,
#  u'ciudades': 8851,
#  u't\xeda': 1727,
#  u'FUERZA': 24320,
#  u'arriesgarnos': 21675,
#  u'hermana': 858,
#  u'hermano': 621,
#  u'Caen': 9756,
#  u't\xedo': 1440,
#  u'Valle': 21025,
#  u'Valla': 10483,
#  u'MAMAAAAAA': 25374,
#  u'Saco': 26059,
#  u'tambin': 15800,
#  u'\u201cderechona': 25331,
#  u'ignoraba': 4605,
#  u'Iron\xeda': 8637,
#  u'Cocinas': 21237,
#  u'TengoAmorEternoA': 16908,
#  u'escrutan': 28871,
#  u'fuera': 318,
#  u'fuere': 15281,
#  u'jueguen': 21996,
#  u'\U0001f60f': 1052,
#  u'\U0001f621\U0001f621\U0001f621\U0001f621': 17783,
#  u'puanworld': 18769,
#  u'Iphone': 4923,
#  u'arrastradas': 9366,
#  u'Honorable': 22260,
#  u'Aix\xf2': 23300,
#  u'Diarias': 9526,
#  u'dialogo': 24059,
#  u'chuchos': 29159,
#  u'wuju': 14792,
#  u'\U0001f31a\U0001f605': 11525,
#  u'administrativos': 10188,
#  u'chino': 5135,
#  u'Staaap': 20704,
#  u'solidaricen': 17761,
#  u'GugaLusto': 5436,
#  u'vamos\U0001f44f': 20017,
#  u'\xa1Muy': 28392,
#  u'golden': 9919,
#  u'pint\xf3': 28488,
#  u'Viendo': 3005,
#  u'\xbfAburrimiento': 16730,
#  u't\xfa\u2665': 22511,
#  u'tocarte': 26324,
#  u'hechastes': 23409,
#  u'ordenada': 23405,
#  u'dni': 25003,
#  u'enfermita': 25276,
#  u'quemierda': 14269,
#  u'PEDAZO': 17426,
#  u'yahoo': 7909,
#  u'CONOZCA': 13331,
#  u'Edgardo': 15688,
#  u'\U0001f631\U0001f62d\U0001f62d\U0001f62d': 27541,
#  u'Colombia': 1053,
#  u'Obsesi\xf3n': 29207,
#  u'Euro': 14627,
#  u'Inviertan': 25520,
#  u'Le': 403,
#  u'La': 60,
#  u'Lo': 110,
#  u'\U0001f496': 5271,
#  u'pinte': 9077,
#  u'etiqueta': 9776,
#  u'pinta': 921,
#  u'odontolog\xeda': 13622,
#  u'absoluta': 3542,
#  u'pensarlo': 4995,
#  u'LE': 1293,
#  u'LC': 17257,
#  u'LA': 275,
#  u'LO': 701,
#  u'LL': 9394,
#  u'playback': 4902,
#  u'traves': 19872,
#  u'aprendi\xf3': 15635,
#  u'Gusta': 8099,
#  u'balada': 18494,
#  u'Gusto': 19575,
#  u'rescatarnos': 28979,
#  u'dictado': 15417,
#  u'pareciera': 27963,
#  u'modest': 11457,
#  u'calidad': 828,
#  u'chihuahue\xf1o': 13826,
#  u'reto': 27777,
#  u'PROTAGONICO': 25347,
#  u'ser\xeda': 1290,
#  u'pr\xf3jimo': 16117,
#  u'CFK': 22832,
#  u'Respiras': 15882,
#  u'tulio': 15071,
#  u'Mabel': 6818,
#  u'l\xedneas': 3170,
#  u'\xbfhablarme': 14379,
#  u'romper': 2110,
#  u'cerrada': 3828,
#  u'combatibles': 25563,
#  u'Llegues': 9972,
#  u'Badajoz': 22463,
#  u'cerrado': 5318,
#  u'pregrado': 28305,
#  u'ganasdepiscineo': 14324,
#  u'TodosConElBronco': 23204,
#  u'fis': 13283,
#  u'empecemos': 25733,
#  u'costado': 7926,
#  u'fic': 3718,
#  u'queguay': 13313,
#  u'fin': 278,
#  u'Him': 21069,
#  u'productivas': 19741,
#  u'twita': 12173,
#  u'avienta': 16162,
#  u'nervios': 1344,
#  u'twits': 21570,
#  u'twitt': 4846,
#  u'inservible': 26179,
#  u'aniervsario': 20907,
#  u'presupone': 23997,
#  u'tenid': 25874,
#  u'arroz': 5536,
#  u'g\xfceno': 21431,
#  u'esensia': 28937,
#  u"callamos'": 22613,
#  u'sacarme': 3038,
#  u'veracruz': 25372,
#  u'100kmQu\xe9': 13303,
#  u'NoPosWow': 12654,
#  u'encerar': 10110,
#  u'solazo': 21186,
#  u'Chivas': 28408,
#  u'goles': 1691,
#  u'videntes': 22563,
#  u'correcta': 5095,
#  u'correcto': 3147,
#  u'transmiciones': 26749,
#  u'curiosidadddd': 28192,
#  u'gameplay': 23208,
#  u'planificando': 21449,
#  u'MarilynMonroe': 20662,
#  u'Nesesito': 11565,
#  u'llegas': 2507,
#  u'quisieras': 28888,
#  u'caramelo': 17446,
#  u'basico': 12336,
#  u'Checate': 23110,
#  u'influyente': 16815,
#  u'MenudoParguela': 15231,
#  u'JAJAJJAJAJJAJAJAJAJ': 18812,
#  u'service': 15053,
#  u'\xbfMEJORO': 27363,
#  u'master': 16039,
#  u'eficiencia': 5510,
#  u'sanguijuelas': 20409,
#  u'Mancera': 18430,
#  u't\xe9rminar': 10109,
#  u'Daddy': 25774,
#  u'celulitis': 4597,
#  u'SPAM': 25923,
#  u'\U0001f44b\U0001f44a': 23237,
#  u'Catalunya': 7215,
#  u'friend': 13950,
#  u'panaaaaaa': 18635,
#  u'conv\xe9': 17522,
#  u'justicia': 2206,
#  u'ajustar': 17581,
#  u'ModoON': 4980,
#  u'DontBuyTheSun': 28692,
#  u'pacientes': 18688,
#  u'afici\xf3n': 1056,
#  u'sitio': 1532,
#  u'malgastar': 23109,
#  u'inseparables': 12458,
#  u'ModoOn': 3755,
#  u'CELULAR': 22352,
#  u'huevadas': 22204,
#  u'cortarse': 7179,
#  u'captas': 15868,
#  u'concedes': 13804,
#  u'buenosdias': 16515,
#  u'eternidad': 5978,
#  u'programacion': 28299,
#  u'Pandora': 14859,
#  u'chispas': 24762,
#  u'Tarima': 26926,
#  u'asamble\xedsta': 13690,
#  u'lavida': 28126,
#  u'majo': 5959,
#  u'multimillonarios': 26446,
#  u'maja': 23648,
#  u'la\U0001f451': 25086,
#  u'cumbia': 4713,
#  u'har\xeda': 3133,
#  u'Randazzo': 18733,
#  u'quebien': 18995,
#  u'MEXxBOL': 21058,
#  u'mostraron': 28388,
#  u'estais': 15170,
#  u"'reconfortante'": 27795,
#  u'jajajajajaajajaja': 27935,
#  u'\u270c\ufe0f': 8579,
#  u'andaluses': 16407,
#  u'Avellana': 16868,
#  u'rico': 572,
#  u'Coataa': 11374,
#  u'rich': 12707,
#  u'ir\xe1': 27061,
#  u'rica': 4014,
#  u'\U0001f648\U0001f49a': 13531,
#  u'plata': 1131,
#  u'plato': 3706,
#  u'pucho': 14561,
#  u'caribe': 8008,
#  u'venen': 12968,
#  u'Petrocaribe': 26842,
#  u'acu\xf1able': 14909,
#  u'rectal': 26892,
#  u'compras': 3237,
#  u'comprar': 727,
#  u'\xbfc\xf3mo': 12303,
#  u'compran': 23080,
#  u'empeore': 10724,
#  u'Borek': 3534,
#  u'sue\xf1os': 1665,
#  u'Nicol\xe1s': 6968,
#  u'ENGA\xd1OSOS': 25956,
#  u'guille': 29080,
#  u'ahorrar': 3697,
#  u'ahorras': 19837,
#  u'\U0001f612\U0001f52bGH2015': 21662,
#  u'hago\U0001f623': 19496,
#  u'cordones': 23800,
#  u'Guayana': 23226,
#  u'fuisteJajajaja': 26038,
#  u'APLAUDO': 18709,
#  u'gasolineras': 14299,
#  u'ira': 5428,
#  u'ire': 5087,
#  u'Advanced': 29123,
#  u'derrite': 8448,
#  u'FOXS2': 17755,
#  u'\u2744\u26c4\u26c4\u2744': 13384,
#  u'plat\xf3': 24985,
#  u'PROFESOR': 17591,
#  u'imponente': 21536,
#  u'\xbfquien': 2071,
#  u'china': 23112,
#  u'encajar': 4842,
#  u'coreograf\xeda': 19830,
#  u'ElChiringuitoDeNeox': 25609,
#  u'colaboraci\xf3n': 25789,
#  u'cuadrados': 6012,
#  u'okkkk': 18588,
#  u'psic\xf3logo': 4669,
#  u'VIVIR': 7350,
#  u'felicidad': 415,
#  u'psic\xf3loga': 5202,
#  u'desaforada': 19528,
#  u'pagaran': 10802,
#  u'corredora': 14428,
#  u'colch\xf3n': 23916,
#  u'Jajajaj': 4225,
#  u'metieras': 18677,
#  u'DILEMA': 15115,
#  u'papasito': 17400,
#  u'administrativo': 27240,
#  u'jurao': 17620,
#  u'bien\U0001f44f\U0001f44f': 18814,
#  u'atasco': 27639,
#  u'medida': 4018,
#  u'colombianos': 26789,
#  u'TDC': 8978,
#  u'sanitaria': 28445,
#  u'nebulizaciones': 26387,
#  u'TDR': 9209,
#  u'TDT': 16887,
#  u'unos': 377,
#  u'Kick': 25735,
#  u'juegan': 1548,
#  u'carteros': 16301,
#  u'hormigas': 20015,
#  u'\xbfCu\xe1l': 5611,
#  u'juegas': 18674,
#  u'Sobre': 2276,
#  u'devuelvenos': 23471,
#  u'Usaba': 22359,
#  u'\U0001f3a4': 27010,
#  u'reinstalar': 18970,
#  u'PuebaVotaAzul': 22627,
#  u'Spotity': 13846,
#  u'relacion': 3121,
#  u'divinas88': 27512,
#  u'agarras': 24477,
#  u'agarrar': 5312,
#  u'amorrrrrr': 18453,
#  u'agarran': 6517,
#  u'ladra': 12355,
#  u'cuidarme': 8496,
#  u'volaste': 21003,
#  u'algun': 1409,
#  u'Trankilo': 19053,
#  u'academia': 4990,
#  u'promete': 4244,
#  u'etica': 24633,
#  u'bellos': 3690,
#  u'desaparecer': 8486,
#  u'prometo': 5585,
#  u'preparando': 8777,
#  u'serrucho': 10968,
#  u'desaparecen': 22770,
#  u'nataci\xf3n': 5996,
#  u'lasso': 20042,
#  u'explota': 26464,
#  u'han': 262,
#  u'Oscar': 2905,
#  u'fieles': 4544,
#  u'adritequeremos': 25960,
#  u'XBOX': 18685,
#  u'hay': 54,
#  u'haz': 22923,
#  u'barbaridades': 18560,
#  u'has': 568,
#  u'felicitaciones': 8731,
#  u'llenado': 16838,
#  u'online': 3989,
#  u'\U0001f44c': 523,
#  u'Caguameria': 12597,
#  u'Brenda': 12351,
#  u'antorchistas': 27233,
#  u'ILIMITADOS': 18397,
#  u'fanatismo': 20810,
#  u'emigrando': 25045,
#  u'muchooo': 11397,
#  u'arbitro': 9440,
#  u'ocasi\xf3n': 18368,
#  u'promet\xed': 12531,
#  u'QUEELM\xc9DICOEMPIECEAPASARCONSULTAMeEncantaLaPuntualidad': 26668,
#  u'culpar': 11599,
#  u'\U0001f648\U0001f648': 26918,
#  u'Estar': 1229,
#  u'Estas': 1498,
#  u'Avisenme': 12424,
#  u'repare': 25191,
#  u'beneficiar': 22955,
#  u'repintar': 26796,
#  u'botadito': 23083,
#  u'\xbfLa': 13525,
#  u'cagones': 17625,
#  u'Facebook': 1179,
#  u'\xbfLe': 20457,
#  u'Respirando': 24152,
#  u'muuucha': 15585,
#  u'Sangre': 16855,
#  u'agregamos': 27255,
#  u'Calle': 11862,
#  u'Calla': 6896,
#  u'alterado': 16304,
#  u'bidet': 27688,
#  u'monta\xf1as': 25673,
#  u'panzas': 19621,
#  u'traballar': 17647,
#  u'invencible': 21892,
#  u'informaci\xf3n': 1538,
#  u'Plis': 20522,
#  u'bendijo': 18911,
#  u'MiMamaMeVaASacarElInternet': 25007,
#  u'Incita': 19662,
#  u'Aaron': 27872,
#  u'desconfiada': 14242,
#  u'todas\U0001f44c\U0001f44f\U0001f481\U0001f602': 28955,
#  u'verdaderamente': 12161,
#  u'16000': 16242,
#  u'EleccionesM\xe9xico2015': 24364,
#  u'solicitada': 28870,
#  u'ubique': 17703,
#  u'normales': 4390,
#  u'realizando': 15754,
#  u'verde': 1247,
#  u'Soda': 11128,
#  u'\xbfBuscas': 6009,
#  u'pencas': 25934,
#  u'admirables': 27437,
#  u'resultado': 2054,
#  u'embolic': 15656,
#  u'pesos': 1876,
#  u'resabiado': 22942,
#  u'emisora': 12142,
#  u'recordarte': 11797,
#  u'publica': 6333,
#  u'moderno': 7818,
#  u'minas': 2128,
#  u'ChoiceSelfieTaker': 17445,
#  u'publico': 5603,
#  u'Yoya': 26439,
#  u'Marenostrum': 14306,
#  u'hicha': 28076,
#  u'tenerlo': 3626,
#  u'tenerla': 7675,
#  u'enga\xf1ado': 6962,
#  u'E': 2004,
#  u'\U0001f64b\U0001f3fc\U0001f64b\U0001f3fc\U0001f64b\U0001f3fc': 12671,
#  u'estremece': 14974,
#  u'transportes': 23948,
#  u'Gardens': 18604,
#  u'WEYYY': 22350,
#  u'DiluvioUniversal': 18507,
#  u'\U0001f62b': 3765,
#  u'faltado': 24720,
#  u'anteponer': 12140,
#  u'entrevista': 1244,
#  u'oso': 27613,
#  u'LeySeca': 7245,
#  u'Bye': 5364,
#  u'T\xc1CHIRA': 20891,
#  u'LASTIMA': 12899,
#  u'cerebros': 5092,
#  u'ense\xf1arte': 26280,
#  u'lara': 24221,
#  u'quemocion': 14601,
#  u'bardeabas': 12606,
#  u'macho': 3550,
#  u'naturalidad': 8123,
#  u'Granollers': 20616,
#  u'caducaron': 10622,
#  u'minuto': 1202,
#  u'Tau': 24460,
#  u'bajen': 9657,
#  u'organos': 12967,
#  u'viralisemos': 19266,
#  u'M\xcd': 18781,
#  u'pela': 23954,
#  u'Tay': 22400,
#  u'viejaaa': 12075,
#  u'montar': 3276,
#  u'Tag': 26029,
#  u'Tal': 2732,
#  u'Tan': 816,
#  u'adorno': 19683,
#  u'bidaa': 23154,
#  u'Europea': 20755,
#  u'M3': 24940,
#  u'ORIGINALES': 26322,
#  u'cumplea\xf1os': 575,
#  u'corazon': 1321,
#  u'AGARRO': 22351,
#  u'adormir': 13584,
#  u'impuesto': 5258,
#  u'\U0001f64a\U0001f64a\U0001f64a\U0001f64a\U0001f64a': 11558,
#  u'Lopez': 9931,
#  u'Me': 32,
#  u'Mg': 20682,
#  u'Mf': 9966,
#  u'oyeron': 15226,
#  u'Mc': 6733,
#  u'Mm': 7256,
#  u'Incompetentes': 15393,
#  u'Mi': 115,
#  u'Geminiana': 13245,
#  u'uff': 5335,
#  u'Mr': 13747,
#  u'My': 2246,
#  u'Mx': 18838,
#  u'ME': 412,
#  u'safeofsaound': 25200,
#  u'MA': 17927,
#  u'MC': 7330,
#  u'MB': 10524,
#  u'MM': 12389,
#  u'MI': 709,
#  u'yoelijoyanbal': 21842,
#  u'etnicas': 23133,
#  u'deduccion': 11160,
#  u'MV': 9197,
#  u'la1\xaa': 24784,
#  u'MP': 4142,
#  u'MS': 19390,
#  u'MZ': 15449,
#  u'REAL': 27502,
#  u'Antes': 1456,
#  u'\xa1Oiga': 12693,
#  u'petroleo': 23920,
#  u'sistemas': 8852,
#  u'mejoro': 6425,
#  u'excluyan': 11367,
#  u'BienEugenia': 11008,
#  u'Jong': 8100,
#  u'vidamejor': 11417,
#  u'Bob': 4515,
#  u'mejora': 2209,
#  u'rayos': 2492,
#  u'PAU2015': 2113,
#  u'raquetball': 20142,
#  u'Secoo': 20445,
#  u'GORDA': 24366,
#  u'NOOOOQUE': 18723,
#  u'SuicideSquad': 22723,
#  u'Invoquemos': 25153,
#  u'Iris': 6607,
#  u'Klaus': 23401,
#  u'Uueueue': 14322,
#  u'beneficio': 5935,
#  u'cuanta': 2156,
#  u'cuanto': 1046,
#  u'Fernet': 20448,
#  u'descance': 27983,
#  u'PERSONAL': 18149,
#  u'valores': 5684,
#  u'DiosPrimero': 17283,
#  u'valoren': 28984,
#  u'PERSONAS': 20685,
#  u'absoluto': 9319,
#  u'JAJAJAJAJAJAJAJA': 6452,
#  u'COMBINACI\xd3N': 21472,
#  u'epiqu\xedsimo': 27179,
#  u'kurcy': 13196,
#  u'apostar': 1868,
#  u'apunta': 21961,
#  u'bastante': 1784,
#  u'dosis': 5470,
#  u'\U0001f62c\U0001f621': 14341,
#  u'litro': 6789,
#  u'Arantza': 12324,
#  u'confiadaaaa': 18181,
#  u'colocan': 17371,
#  u'risas': 1895,
#  u'ataq': 18311,
#  u'tendriamoa': 27554,
#  u'Esmeraldas': 12779,
#  u'petado': 7805,
#  u'oculus': 24760,
#  u'Molt': 25294,
#  u'Tersch': 29163,
#  u'mango': 16337,
#  u'Mola': 7736,
#  u'mezcla': 23896,
#  u'manga': 6974,
#  u'conversi\xf3n': 6449,
#  u'Animalista': 11078,
#  u'nubes\u2601\ufe0f\u2601\ufe0f\u2601\ufe0f': 24379,
#  u'nsi': 8479,
#  u'Elias': 5480,
#  u'Absolutamente': 6187,
#  u'p\xedo': 22498,
#  u'abdominales': 6222,
#  u'bitcheslasodio': 14381,
#  u'arrepientas': 6772,
#  u'faveo': 22884,
#  u'Agricultura\u2026': 21671,
#  u'favee': 6683,
#  u'favea': 7293,
#  u'DENTISTAS': 12138,
#  u'candidatos': 1681,
#  u'seria\U0001f3bc': 14039,
#  u'tr\xe1ficocr': 22191,
#  u'enamorarme': 9093,
#  u'temario': 4892,
#  u'cr\xe9dito': 11425,
#  u'sorteo': 3187,
#  u'temes': 16523,
#  u'ps\xedquicos': 22141,
#  u'aprox': 9727,
#  u'\u2b07\ufe0f': 13510,
#  u'nicoduranchupala': 24408,
#  u'hostia': 8917,
#  u'enhorabuena': 4559,
#  u'promocionar': 23572,
#  u'salado': 26615,
#  u'Mat\xedas': 21356,
#  u'ni\xf1os': 1097,
#  u'mascotas': 21515,
#  u'amamos': 3322,
#  u'Muerto': 15425,
#  u'caracterizan': 16716,
#  u'Muerte': 7349,
#  u'Urbanizaci\xf3n': 26699,
#  u'\xa1Claro': 6723,
#  u'troll': 9096,
#  u'792': 16906,
#  u'trola': 3770,
#  u'trauma': 18972,
#  u'cejitas': 16945,
#  u'internet': 622,
#  u'se\xf1or\xedo': 8422,
#  u'chicooo': 18016,
#  u"m'han": 22336,
#  u'tienen': 201,
#  u"No'mbre": 29040,
#  u'sonar': 26355,
#  u'tienes': 267,
#  u'gordos': 5898,
#  u'inferiores': 18296,
#  u'ordenar': 16827,
#  u'Nuestra': 6053,
#  u'Amamos': 28334,
#  u'envidienme': 26295,
#  u'culturales': 9589,
#  u'divertirse': 7548,
#  u'presiosa': 6467,
#  u'Nuestro': 8165,
#  u'LLiderTeNecesitamosVIVO': 2129,
#  u'one': 4706,
#  u'falsos': 9065,
#  u'casquito': 20432,
#  u'FraseDelD\xeda': 25882,
#  u'apodo': 24078,
#  u'Palos': 17000,
#  u'ARMENTA': 10306,
#  u'escamoso': 26631,
#  u'REGI\xd2N': 10308,
#  u'parando': 28611,
#  u'ElGobiernoDelCambio': 15773,
#  u'parecian': 24444,
#  u'cerebro': 1575,
#  u'comediante': 3260,
#  u'fcblive': 12794,
#  u'aguantar\xedan': 15159,
#  u'detras': 4308,
#  u'Ciao': 29106,
#  u'Televisa': 4963,
#  u'\U0001f495\U0001f495\U0001f64c': 16214,
#  u'FELICIDAD': 27645,
#  u'\u201ceso\u201d': 12577,
#  u'quierooooo': 15084,
#  u'politicos': 11791,
#  u'Alicia': 18583,
#  u'la5inoamer8cana': 24565,
#  u'invidentes': 14110,
#  u'Halo': 5899,
#  u'Shalom': 9752,
#  u'ayudaaaaaaaa': 12705,
#  u'chavrria': 17677,
#  u'estad': 26072,
#  u'decirte': 3193,
#  u'invito': 1773,
#  u'\xe9sas': 19457,
#  u'AFUERA': 10340,
#  u'Shinobu': 20109,
#  u'Cher': 15338,
#  u'Drog\xe1ndome': 24030,
#  u'Aguado': 10587,
#  u'SVDivinity': 18680,
#  u'Chen': 26476,
#  u'\U0001f62d\U0001f62d\U0001f62d\U0001f62d\U0001f62d\U0001f62d\U0001f62d\U0001f62d': 10025,
#  u'matando': 2089,
#  u'Jug\xf3': 14671,
#  u'FaustoVallejo': 15937,
#  u'Aaaaah': 11243,
#  u'soviets': 7481,
#  u'adornando': 15717,
#  u'preguntar\xe1n': 28537,
#  u'3': 129,
#  u'resolviendo': 26182,
#  u'descolonizaci\xf3n': 25029,
#  u'zamarripachoforo': 16973,
#  u'hermanos': 2915,
#  u'seguidor': 6985,
#  u'seguidos': 4023,
#  u'tuyos': 3068,
#  u'TTTTTTTTTTTTTTTT': 25824,
#  u'Caliente': 9908,
#  u'extranjeros': 9038,
#  u'creer\xeda': 6283,
#  u'sufrido': 21654,
#  u'Ocurre': 11616,
#  u'Gracies': 20176,
#  u'sinsorgo': 22527,
#  u'\xabEl': 24418,
#  u'VotaPANPuebla': 4858,
#  u'GameInsight': 8478,
#  u'tiki': 6054,
#  u'indignaci\xf3n': 10827,
#  u'folloback': 6862,
#  u'prevenido': 23397,
#  u'Revista': 27921,
#  u'diria': 5779,
#  u'evitado': 11868,
#  u'correcciones': 27634,
#  u'Ringo': 22458,
#  u'chupaba': 12406,
#  u'temporada': 925,
#  u'AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAHHHH': 22464,
#  u'YoMeEntiendo': 24368,
#  u'Ixcaquixtla': 23142,
#  u'trigrillo': 16186,
#  u'venden': 2494,
#  u'Aww': 14964,
#  u'vended': 19595,
#  u'apu\xf1alada': 8834,
#  u'persegu\xeda': 14543,
#  u'Jonas': 7244,
#  u'vender': 2169,
#  u'Circe': 24326,
#  u'punta': 3443,
#  u'planes': 1208,
#  u'punto': 767,
#  u'Vaaaamos': 15471,
#  u'Cosmos': 6567,
#  u'adultos': 26533,
#  u's': 981,
#  u'arrepentir\xe1s': 23927,
#  u'DAROSNO': 29262,
#  u'RESPALDAN': 19183,
#  u'drogo': 18127,
#  u'Ganso': 18682,
#  u'droga': 5122,
#  u'mamona': 5075,
#  u'measo': 18245,
#  u'Corgatelli': 17794,
#  u'peor\xbb': 18515,
#  u'Vete': 5379,
#  u'entregar': 24137,
#  u'pioola': 20078,
#  u'Maquina': 22291,
#  u'TESTRA': 13272,
#  u'tomen': 3136,
#  u'divirtieran': 23504,
#  u'Jaumave': 12274,
#  u'dpto': 13930,
#  u'justita': 14658,
#  u'IR\xc9': 18298,
#  u'comen': 9005,
#  u'vomita': 23867,
#  u'Terminar': 20511,
#  u'hashtag': 3119,
#  u'vomito': 14931,
#  u'PIJA': 16923,
#  u'trenzas': 24184,
#  u'cari\xf1os': 16291,
#  u'Ribera': 12798,
#  u'Dimitir': 15679,
#  u'hastag': 26739,
#  u'Sabado': 18023,
#  u'evade': 9570,
#  u'chicles': 15221,
#  u'cura': 2966,
#  u'Masajes': 14443,
#  u'jajajajajajajsja': 10447,
#  u'6RACIASXAVI': 26025,
#  u'nombreee': 10360,
#  u'Kiko': 21701,
#  u'estrespreexamenes': 19356,
#  u'chulitas': 29181,
#  u'UTA': 13809,
#  u'hablarlo': 14530,
#  u'materia': 5392,
#  u'hablarle': 4661,
#  u'confirmado': 10717,
#  u'reaccionar': 24503,
#  u'PADRES': 28682,
#  u'contemplar': 6194,
#  u'youtubers': 10299,
#  u'juntabamos': 28483,
#  u'Agencia': 21595,
#  u'Ahre': 4808,
#  u'sobraban': 10265,
#  u'pelitos': 14533,
#  u'Estelita': 17924,
#  u'chabon': 1339,
#  u'arruinan': 9733,
#  u've\xe1is': 19292,
#  u'fieraaa': 16804,
#  u'NAH': 22329,
#  u'NAL': 16373,
#  u'nivelazo': 8433,
#  u'abrazando': 16895,
#  u'TeEsperamos': 8050,
#  u'arruinar': 5591,
#  u'Vengan': 19754,
#  u'temblor': 5963,
#  u'discutido': 12464,
#  u'aborto': 6759,
#  u'canciones': 804,
#  u'saluden': 6551,
#  u'perdi\xf3': 3399,
#  u'ladilla': 23889,
#  u'ORGULLO': 11702,
#  u'Vengas': 24040,
#  u'Nochee': 10376,
#  u'nLibre': 13551,
#  u'rompe': 2299,
#  u'rompo': 7061,
#  u'MadreDelAmorHermoso': 22849,
#  u'bueena': 10556,
#  u'nuncamas': 11086,
#  u'teng\xe1is': 19596,
#  u'Noches': 7076,
#  u'suma': 5386,
#  u'l\xedder': 3025,
#  u'reventado': 17836,
#  u'enero': 7046,
#  u'Sergio': 2112,
#  u'Blatter': 3326,
#  u'Pasaron': 20389,
#  u'Belleza': 21904,
#  u'burpees': 18992,
#  u'grua': 18128,
#  u'divino': 2277,
#  u'tvd': 12656,
#  u'divina': 3357,
#  u'pregunten': 3108,
#  u'aberraci\xf3n': 15037,
#  u'perdia': 16472,
#  u'perdio': 7666,
#  u'protestemos': 9489,
#  u'notaba': 23969,
#  u'jaajaja': 21935,
#  u'ense\xf1\xe9is': 18478,
#  u'preguntes': 7203,
#  u'callarme': 25769,
#  u'guagua': 29293,
#  u'AJEDREZ': 27487,
#  u'comprarse': 13009,
#  u'romp\xed': 10769,
#  u'Despr\xe9s': 12216,
#  u'Monumental': 8214,
#  u'vacilon': 11852,
#  u'recaudaci\xf3n': 8457,
#  u'importar\U0001f486\u270b': 28506,
#  u'luces': 5806,
#  u'holaa': 15112,
#  u'ortogr\xe1ficas': 9082,
#  u'subeeeee': 28051,
#  u'lucen': 13685,
#  u'pel\xedcula': 630,
#  u'Arrancan': 25362,
#  u'\U0001f535\u26ab\ufe0f\U0001f414': 11665,
#  u'victimista': 15451,
#  u'Ni': 501,
#  u'Antofagasta': 5086,
#  u'No': 33,
#  u'Na': 7152,
#  u'muajaja': 18893,
#  u'inv\xedtenme': 21750,
#  u'60\u20ac': 25315,
#  u'MOJO': 14362,
#  u'NI': 3465,
#  u'peatonal': 27687,
#  u'vaaamos': 12679,
#  u'NO': 221,
#  u'NA': 18858,
#  u'NY': 14844,
#  u'discutis': 25462,
#  u'discutir': 2955,
#  u'DopeBTSenlos40': 26504,
#  u'Sabrina': 8485,
#  u'NV': 10719,
#  u'dormir': 113,
#  u'ir\xe1n': 8547,
#  u'MiPeorPesadilla': 25747,
#  u'paramatarlas': 19480,
#  u'aplastante': 17852,
#  u'alemania': 13457,
#  u'muchisiimoo': 11951,
#  u'Octavos': 16612,
#  u'weyes': 10100,
#  u'yayo': 23331,
#  u'C\xe1mara': 26593,
#  u'trompa\U0001f44c\U0001f3fc': 16068,
#  u'marc\xf3n': 24430,
#  u'desobendiente\U0001f3a7': 27014,
#  u'cheto': 7272,
#  u'chingaso': 13054,
#  u'Rutina': 17549,
#  u'pulp': 11146,
#  u'Nandin': 12604,
#  u'crear': 4073,
#  u'creas': 3670,
#  u'cuesti\xf3n': 5443,
#  u'perdamos': 12638,
#  u'apuraba': 15946,
#  u'goleador': 12529,
#  u'mundo': 131,
#  u'\xbfPodr\xedas': 18351,
#  u'murcia': 24648,
#  u'crean': 4036,
#  u'Real': 1305,
#  u'yoga': 8874,
#  u'PENS\xc9': 25367,
#  u'abstinencia': 24362,
#  u'HAGO': 8725,
#  u'list\xedsimos': 29150,
#  u'LLORES': 10065,
#  u'Lady': 27322,
#  u'raju\xf1en': 13796,
#  u'inventan': 7012,
#  u'inventar': 24898,
#  u'c\xf3digo': 4733,
#  u'sinverguenza': 10370,
#  u'natalie': 17487,
#  u'posible': 1199,
#  u'parejas': 4243,
#  u'quedar\xe9': 12056,
#  u'envidiosas': 21524,
#  u'quedar\xe1': 6267,
#  u'pechugas': 17484,
#  u'c\xe1mara': 1910,
#  u'petando': 8072,
#  u'Tendr\xedas': 23485,
#  u'pas\xe9': 7315,
#  u'AMIGA': 6855,
#  u'mamao': 24777,
#  u'respondido': 7284,
#  u'pas\xf3': 1257,
#  u'Fin': 5912,
#  u'Baldizon': 17324,
#  u'dekadaganada': 19693,
#  u'\U0001f602\U0001f3a2': 18954,
#  u'inviernos': 29474,
#  u'hipersexualiza': 29018,
#  u'cartera': 21642,
#  u'ignorancia': 3158,
#  u'HUMO': 12089,
#  u'Rodalies': 4570,
#  u'paisajeeeeeeee': 26491,
#  u'feria': 2395,
#  u'trabajaaaar': 28289,
#  u'activao': 18575,
#  u'Melany': 14380,
#  u'primaaaaaaaaaaa\u2764': 20561,
#  u'tusa': 28225,
#  u'abuso\U0001f601\U0001f601\U0001f602': 18631,
#  u'sang': 27147,
#  u'Enamorarse': 14588,
#  u'sano': 11002,
#  u'habr\xe1': 799,
#  u'pase': 587,
#  u'pasa': 159,
#  u'guita': 7447,
#  u'paso': 328,
#  u'pendientes': 9117,
#  u'Reyes': 9288,
#  u'MULTINIVEL': 19381,
#  u'll\xe1mame': 8509,
#  u'PelayoAlcaldesa': 24204,
#  u'MEDIO': 23078,
#  u'pecado': 3937,
#  u'estupidos': 9480,
#  u'jsuticia': 28767,
#  u'full': 1629,
#  u'editorial': 26875,
#  u'Charlie': 2894,
#  u'obscuridad': 14491,
#  u'Recomi\xe9ndales': 9081,
#  u'reprocharle': 12699,
#  u'doliendo': 19047,
#  u'Reina': 28226,
#  u'uruguayos': 23280,
#  u'atracaron': 18592,
#  u'susa': 19145,
#  u'sali\xe9ramos': 29041,
#  u'nUyVengaRespete': 19957,
#  u'depara': 20558,
#  u'\xa1': 2408,
#  u'pena\U0001f631': 21432,
#  u'nuevas': 4374,
#  u'PUTATOS': 22308,
#  u'memesectario': 16728,
#  u'mori': 7915,
#  u'matarte': 24641,
#  u'nomas': 2555,
#  u'Subir': 14634,
#  u'HASTA': 3311,
#  u'alarde': 13133,
#  u'Juegos': 21621,
#  u'abrace\U0001f648\U0001f49f': 12890,
#  u'Adidas': 13684,
#  u'Raja': 19395,
#  u'Jajja': 26252,
#  u'bancan': 7231,
#  u'bancas': 6192,
#  u'bancar': 6112,
#  u'coincidencia': 5566,
#  u'merecidos': 15738,
#  u'Castellar': 21795,
#  u'Eurovision2015': 8346,
#  u'logran': 21080,
#  u'meharto': 28925,
#  u'logras': 6161,
#  u'lograr': 2696,
#  u'lloracomocerda': 17210,
#  u'Quinta': 6601,
#  u'desilucionado': 18097,
#  u'juve': 23489,
#  ...}

# %%
dict_file = open("./data/ann/dicFile_50_50.p","wb")
pickle.dump(dict_50_50, dict_file)

# %%
vecfile = open("./data/ann/vectors_50_50.txt","w")
pickle.dump(vecorp_50_50, vecfile)

# %%
vecorp_50_50.to_csv('./data/ann/vectors_50_50_readable.txt',sep='|',index=False)

# %%
saveDict("./data/ann/dicFile_50_50.npy", dict_50_50)
